# %%
# %load_ext autoreload
# %autoreload 2
import sys
sys.path.append('..')
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
from simulator.utils import *

simulator = define_simulator(demographic_universe={"age": [0, 1, 2, 3]})
users = simulator.generate_users(n_users=1)
user = users[0]
print(f"User Demographic Profile: {user.demographic_profile}")
print(f"User Starting HHS: {user.HHS}\n")

print(f"Pillars and Missions are selected weekly by the user. No additional interventions (recommendations).")

user.run_mission_loop()
user.plot_progress()
# Out:
# User Demographic Profile: (1,)
# User Starting HHS: {'Diet': 3, 'Physical Activity': 3, 'Smoking': 4, 'Alcohol': 9, 'Mental Wellbeing': 5}
#
# Pillars and Missions are selected weekly by the user. No additional interventions (recommendations).
